# %% [markdown]
# <a href="https://colab.research.google.com/github/MDAnsaar25/Hello-Python/blob/main/Hello_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#My first program**

# %%
print("hello world")
# Out:
# hello world

# %%
print(5+5)
# Out:
# 10

# %% [markdown]
# #Data Types

# %%
a = 5 #integer

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
b=10.5
print(type(b))
# Out:
# <class 'float'>

# %%
c="Thejaswi"
print(type(c))
# Out:
# <class 'str'>

# %%
d="10"
print(type(d))
# Out:
# <class 'str'>

# %%
e=5+6j
print(type(e))
# Out:
# <class 'complex'>

# %%
f = True
print(type(f))
# Out:
# <class 'bool'>

# %% [markdown]
# #Variables

# %%
name = "Thejaswi"
print(name)
# Out:
# Thejaswi

# %%
age=18
print(age)
# Out:
# 18

# %% [markdown]
# #Input Statements

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: Mohanlal
# Mohanlal

# %%
age = int(input("enter the age")) #type Casting
print(age)
print(type(age))
# Out:
# enter the age18
# 18
# <class 'int'>

# %%
thursclass = input("Did Thejaswi attended today's class ?")
print(thursclass)
print(type(thursclass))
# Out:
# Did Thejaswi attended today's class ?False
# False
# <class 'str'>
